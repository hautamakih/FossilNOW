# %%
# %cd ../
# Out:
# /Users/Henri/Data_Science/Data_Science_project/FossilNOW

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8')
plt.rcParams.update({'font.size': 8})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/DS/lib/python3.10/site-packages/matplotlib/style/core.py:127, in use(style)
#     126 try:
# --> 127     rc = rc_params_from_file(style, use_default_template=False)
#     128     _apply_style(rc)
#
# File /opt/anaconda3/envs/DS/lib/python3.10/site-packages/matplotlib/__init__.py:852, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     838 """
#     839 Construct a `RcParams` from file *fname*.
#     840
#    (...)
#     850     parameters specified in the file. (Useful for updating dicts.)
#     851 """
# --> 852 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     854 if not use_default_template:
#
# File /opt/anaconda3/envs/DS/lib/python3.10/site-packages/matplotlib/__init__.py:778, in _rc_params_in_file(fname, transform, fail_on_error)
#     777 rc_temp = {}
# --> 778 with _open_file_or_url(fname) as fd:
#     779     try:
#
# File /opt/anaconda3/envs/DS/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#
# File /opt/anaconda3/envs/DS/lib/python3.10/site-packages/matplotlib/__init__.py:755, in _open_file_or_url(fname)
#     754     encoding = "utf-8"
# --> 755 with open(fname, encoding=encoding) as f:
#     756     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-v0_8'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /Users/Henri/Data_Science/Data_Science_project/FossilNOW/code/examine.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/Henri/Data_Science/Data_Science_project/FossilNOW/code/examine.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> plt.style.use('seaborn-v0_8')
#       <a href='vscode-notebook-cell:/Users/Henri/Data_Science/Data_Science_project/FossilNOW/code/examine.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> plt.rcParams.update({'font.size': 8})
#
# File /opt/anaconda3/envs/DS/lib/python3.10/site-packages/matplotlib/style/core.py:130, in use(style)
#     128     _apply_style(rc)
#     129 except IOError as err:
# --> 130     raise IOError(
#     131         "{!r} not found in the style library and input is not a "
#     132         "valid URL or path; see `style.available` for list of "
#     133         "available styles".format(style)) from err
#
# OSError: 'seaborn-v0_8' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
path = "data/AllSites_SiteOccurrences_AllGenera_26.1.24.csv"

df = pd.read_csv(path)

# %%
df.head()
# Out:
#         SITE_NAME  Equus  Coelodonta  Bos  Gazella  Ursus  Vulpes  Cervus  \
# 0       Aba Zawei      1           1    1        1      0       0       0
# 1    Abric Romani      1           0    1        0      1       1       1
# 2  Acheng_Jiaojie      0           0    0        0      0       0       1
# 3      Adler cave      1           0    0        0      0       1       0
# 4         Adyrgan      1           0    0        1      0       0       0
#
#    Canis  Sus  ...  Total_Gen_Count  Large_GenCount  Small_GenCount  \
# 0      0    0  ...                4               4               0
# 1      1    1  ...               12              12               0
# 2      0    0  ...                7               5               2
# 3      1    0  ...               10               5               5
# 4      0    0  ...               11               5               6
#
#    smallperlarge  smallprop  Herb_GenCount  Nonherb_GenCount  DietRatio  \
# 0            0.0   0.000000              4                 0        NaN
# 1            0.0   0.000000              6                 5        1.2
# 2            0.4   0.285714              5                 2        2.5
# 3            1.0   0.500000              6                 4        1.5
# 4            1.2   0.545455             11                 0        NaN
#
#    HerbProp  mid_age
# 0  1.000000   0.0265
# 1  0.500000   0.0550
# 2  0.714286   0.2100
# 3  0.600000   0.0275
# 4  1.000000   2.2000
#
# [5 rows x 474 columns]

# %%
path2 = "data/FossilGenera_MammalMassDiet_Jan24.csv"
df2 = pd.read_csv(path2)

df2.head()
# Out:
#           Genus           Order          Family      MassSource         Massg  \
# 0     Abudhabia        Rodentia         Muridae  Family average  1.343147e+02
# 1  Aceratherium  Perissodactyla  Rhinocerotidae           Cooke  1.099006e+06
# 2      Acinonyx       Carnivora         Felidae       Phylacine  4.670000e+04
# 3  Aepyosciurus        Rodentia       Sciuridae             NOW  2.860000e+02
# 4       Aeretes        Rodentia       Sciuridae       Phylacine  7.324000e+02
#
#     LogMass LargeSmall SizeClass           Diet DietSource
# 0  2.128124      Small     small      Herbivore  Phylacine
# 1  6.041000      Large     large      Herbivore  Phylacine
# 2  4.669317      Large     large  Non-Herbivore  Phylacine
# 3  2.456366      Small     small      Herbivore  Phylacine
# 4  2.864748      Small     small      Herbivore  Phylacine

# %%
path3 = "data/DentalTraits_Genus_PPPA.csv"

df3 = pd.read_csv(path3)

df3.head()
# Out:
#            Genus    n    Mass.g_Mean  Diet.Plant_Mean  HYP_Mean  LOP_Mean  \
# 0          Addax  1.0   70000.300000            100.0       3.0       2.0
# 1      Aepyceros  1.0   52500.100000            100.0       3.0       2.0
# 2     Alcelaphus  1.0  171001.500000            100.0       3.0       2.0
# 3          Alces  1.0  356998.000000            100.0       1.0       2.0
# 4  Allochrocebus  3.0    5708.333333             90.0       1.0       0.0
#
#    FCT_AL_Mean  FCT_OL_Mean  FCT_SF_Mean  BUN_Mean  ...  HYP_Mode  LOP_Mode  \
# 0          0.0          1.0          1.0       0.0  ...         3         2
# 1          0.0          1.0          0.0       0.0  ...         3         2
# 2          0.0          1.0          0.0       0.0  ...         3         2
# 3          1.0          1.0          0.0       0.0  ...         1         2
# 4          0.0          0.0          0.0       1.0  ...         1         0
#
#    FCT_AL_Mode  FCT_OL_Mode  FCT_SF_Mode  BUN_Mode            Order  \
# 0            0            1          1.0         0  Cetartiodactyla
# 1            0            1          0.0         0  Cetartiodactyla
# 2            0            1          0.0         0  Cetartiodactyla
# 3            1            1          0.0         0  Cetartiodactyla
# 4            0            0          0.0         1         Primates
#
#    ConsInGenhyp ConsInGen_bun  Unnamed: 21
# 0          True          True          NaN
# 1          True          True          NaN
# 2          True          True          NaN
# 3          True          True          NaN
# 4          True          True          NaN
#
# [5 rows x 22 columns]

# %%
path3 = "data/DentalTraits_Genus_PPPA.csv"

df3 = pd.read_csv(path3)

df3.head()
# Out:
#            Genus    n    Mass.g_Mean  Diet.Plant_Mean  HYP_Mean  LOP_Mean  \
# 0          Addax  1.0   70000.300000            100.0       3.0       2.0
# 1      Aepyceros  1.0   52500.100000            100.0       3.0       2.0
# 2     Alcelaphus  1.0  171001.500000            100.0       3.0       2.0
# 3          Alces  1.0  356998.000000            100.0       1.0       2.0
# 4  Allochrocebus  3.0    5708.333333             90.0       1.0       0.0
#
#    FCT_AL_Mean  FCT_OL_Mean  FCT_SF_Mean  BUN_Mean  ...  HYP_Mode  LOP_Mode  \
# 0          0.0          1.0          1.0       0.0  ...         3         2
# 1          0.0          1.0          0.0       0.0  ...         3         2
# 2          0.0          1.0          0.0       0.0  ...         3         2
# 3          1.0          1.0          0.0       0.0  ...         1         2
# 4          0.0          0.0          0.0       1.0  ...         1         0
#
#    FCT_AL_Mode  FCT_OL_Mode  FCT_SF_Mode  BUN_Mode            Order  \
# 0            0            1          1.0         0  Cetartiodactyla
# 1            0            1          0.0         0  Cetartiodactyla
# 2            0            1          0.0         0  Cetartiodactyla
# 3            1            1          0.0         0  Cetartiodactyla
# 4            0            0          0.0         1         Primates
#
#    ConsInGenhyp ConsInGen_bun  Unnamed: 21
# 0          True          True          NaN
# 1          True          True          NaN
# 2          True          True          NaN
# 3          True          True          NaN
# 4          True          True          NaN
#
# [5 rows x 22 columns]
